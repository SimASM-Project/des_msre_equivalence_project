# %% [markdown]
# # MSRE Verification: Hybrid Topology
#
# A **hybrid queueing network** combining $m$ tandem stations with a fork-join section of $b$ parallel branches (`hybrid_m_b`). This topology tests mixed serial-parallel structures. Each station has 5 servers.
#
# ## Macro-Step Refinement Equivalence (MSRE)
#
# Each cell below verifies that two formalism translations produce **identical observable labels at every tick boundary**.
#
# **Notebook parameters**: `seed=42`, `run_length=100.0`.

# %%
import json
try:
    import simasm
    if simasm.__version__ < "0.8.0":
        raise ImportError(f"simasm {simasm.__version__} < 0.8.0")
except ImportError:
    # %pip install -q "simasm>=0.8.0"
    import simasm
assert simasm.__version__ >= "0.8.0", f"Requires simasm >= 0.8.0, got {simasm.__version__}"

# %% [markdown]
# ## hybrid (2,2): 2 tandem + 2 branches

# %%
# %%simasm verify
# // MSRE Verification: hybrid_2_2 EG vs ACD
# // Generated by generate_msre_configs.py
#
# verification hybrid_2_2_eg_acd_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_2_2_eg.simasm"
#         import ACD from "../models/acd/hybrid/hybrid_2_2_acd.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "branch_queue_1 > 0"
#         label queue_3_nonempty for ACD: "marking(BQ_1) > 0"
#         label server_3_busy for EG: "branch_server_1 > 0"
#         label server_3_busy for ACD: "marking(BS_1) < num_servers"
#         label queue_4_nonempty for EG: "branch_queue_2 > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_2) > 0"
#         label server_4_busy for EG: "branch_server_2 > 0"
#         label server_4_busy for ACD: "marking(BS_2) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_2_2 EG vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_2_2_eg_devs_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_2_2_eg.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_2_2_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "branch_queue_1 > 0"
#         label queue_3_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_3_busy for EG: "branch_server_1 > 0"
#         label server_3_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_4_nonempty for EG: "branch_queue_2 > 0"
#         label queue_4_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_4_busy for EG: "branch_server_2 > 0"
#         label server_4_busy for DEVS: "Branch_2_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_2_2 ACD vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_2_2_acd_devs_msre:
#
#     models:
#         import ACD from "../models/acd/hybrid/hybrid_2_2_acd.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_2_2_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(BQ_1) > 0"
#         label queue_3_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_3_busy for ACD: "marking(BS_1) < num_servers"
#         label server_3_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_2) > 0"
#         label queue_4_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_4_busy for ACD: "marking(BS_2) < num_servers"
#         label server_4_busy for DEVS: "Branch_2_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## hybrid (2,3): 2 tandem + 3 branches

# %%
# %%simasm verify
# // MSRE Verification: hybrid_2_3 EG vs ACD
# // Generated by generate_msre_configs.py
#
# verification hybrid_2_3_eg_acd_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_2_3_eg.simasm"
#         import ACD from "../models/acd/hybrid/hybrid_2_3_acd.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "branch_queue_1 > 0"
#         label queue_3_nonempty for ACD: "marking(BQ_1) > 0"
#         label server_3_busy for EG: "branch_server_1 > 0"
#         label server_3_busy for ACD: "marking(BS_1) < num_servers"
#         label queue_4_nonempty for EG: "branch_queue_2 > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_2) > 0"
#         label server_4_busy for EG: "branch_server_2 > 0"
#         label server_4_busy for ACD: "marking(BS_2) < num_servers"
#         label queue_5_nonempty for EG: "branch_queue_3 > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_3) > 0"
#         label server_5_busy for EG: "branch_server_3 > 0"
#         label server_5_busy for ACD: "marking(BS_3) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_2_3 EG vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_2_3_eg_devs_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_2_3_eg.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_2_3_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "branch_queue_1 > 0"
#         label queue_3_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_3_busy for EG: "branch_server_1 > 0"
#         label server_3_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_4_nonempty for EG: "branch_queue_2 > 0"
#         label queue_4_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_4_busy for EG: "branch_server_2 > 0"
#         label server_4_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_5_nonempty for EG: "branch_queue_3 > 0"
#         label queue_5_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_5_busy for EG: "branch_server_3 > 0"
#         label server_5_busy for DEVS: "Branch_3_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_2_3 ACD vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_2_3_acd_devs_msre:
#
#     models:
#         import ACD from "../models/acd/hybrid/hybrid_2_3_acd.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_2_3_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(BQ_1) > 0"
#         label queue_3_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_3_busy for ACD: "marking(BS_1) < num_servers"
#         label server_3_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_2) > 0"
#         label queue_4_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_4_busy for ACD: "marking(BS_2) < num_servers"
#         label server_4_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_3) > 0"
#         label queue_5_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_5_busy for ACD: "marking(BS_3) < num_servers"
#         label server_5_busy for DEVS: "Branch_3_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## hybrid (2,4): 2 tandem + 4 branches

# %%
# %%simasm verify
# // MSRE Verification: hybrid_2_4 EG vs ACD
# // Generated by generate_msre_configs.py
#
# verification hybrid_2_4_eg_acd_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_2_4_eg.simasm"
#         import ACD from "../models/acd/hybrid/hybrid_2_4_acd.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "branch_queue_1 > 0"
#         label queue_3_nonempty for ACD: "marking(BQ_1) > 0"
#         label server_3_busy for EG: "branch_server_1 > 0"
#         label server_3_busy for ACD: "marking(BS_1) < num_servers"
#         label queue_4_nonempty for EG: "branch_queue_2 > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_2) > 0"
#         label server_4_busy for EG: "branch_server_2 > 0"
#         label server_4_busy for ACD: "marking(BS_2) < num_servers"
#         label queue_5_nonempty for EG: "branch_queue_3 > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_3) > 0"
#         label server_5_busy for EG: "branch_server_3 > 0"
#         label server_5_busy for ACD: "marking(BS_3) < num_servers"
#         label queue_6_nonempty for EG: "branch_queue_4 > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_4) > 0"
#         label server_6_busy for EG: "branch_server_4 > 0"
#         label server_6_busy for ACD: "marking(BS_4) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             ACD -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             ACD -> server_6_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_2_4 EG vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_2_4_eg_devs_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_2_4_eg.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_2_4_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "branch_queue_1 > 0"
#         label queue_3_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_3_busy for EG: "branch_server_1 > 0"
#         label server_3_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_4_nonempty for EG: "branch_queue_2 > 0"
#         label queue_4_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_4_busy for EG: "branch_server_2 > 0"
#         label server_4_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_5_nonempty for EG: "branch_queue_3 > 0"
#         label queue_5_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_5_busy for EG: "branch_server_3 > 0"
#         label server_5_busy for DEVS: "Branch_3_server_count > 0"
#         label queue_6_nonempty for EG: "branch_queue_4 > 0"
#         label queue_6_nonempty for DEVS: "Branch_4_queue_count > 0"
#         label server_6_busy for EG: "branch_server_4 > 0"
#         label server_6_busy for DEVS: "Branch_4_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_2_4 ACD vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_2_4_acd_devs_msre:
#
#     models:
#         import ACD from "../models/acd/hybrid/hybrid_2_4_acd.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_2_4_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(BQ_1) > 0"
#         label queue_3_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_3_busy for ACD: "marking(BS_1) < num_servers"
#         label server_3_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_2) > 0"
#         label queue_4_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_4_busy for ACD: "marking(BS_2) < num_servers"
#         label server_4_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_3) > 0"
#         label queue_5_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_5_busy for ACD: "marking(BS_3) < num_servers"
#         label server_5_busy for DEVS: "Branch_3_server_count > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_4) > 0"
#         label queue_6_nonempty for DEVS: "Branch_4_queue_count > 0"
#         label server_6_busy for ACD: "marking(BS_4) < num_servers"
#         label server_6_busy for DEVS: "Branch_4_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             ACD -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             ACD -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## hybrid (3,2): 3 tandem + 2 branches

# %%
# %%simasm verify
# // MSRE Verification: hybrid_3_2 EG vs ACD
# // Generated by generate_msre_configs.py
#
# verification hybrid_3_2_eg_acd_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_3_2_eg.simasm"
#         import ACD from "../models/acd/hybrid/hybrid_3_2_acd.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "branch_queue_1 > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_1) > 0"
#         label server_4_busy for EG: "branch_server_1 > 0"
#         label server_4_busy for ACD: "marking(BS_1) < num_servers"
#         label queue_5_nonempty for EG: "branch_queue_2 > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_2) > 0"
#         label server_5_busy for EG: "branch_server_2 > 0"
#         label server_5_busy for ACD: "marking(BS_2) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_3_2 EG vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_3_2_eg_devs_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_3_2_eg.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_3_2_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "branch_queue_1 > 0"
#         label queue_4_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_4_busy for EG: "branch_server_1 > 0"
#         label server_4_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_5_nonempty for EG: "branch_queue_2 > 0"
#         label queue_5_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_5_busy for EG: "branch_server_2 > 0"
#         label server_5_busy for DEVS: "Branch_2_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_3_2 ACD vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_3_2_acd_devs_msre:
#
#     models:
#         import ACD from "../models/acd/hybrid/hybrid_3_2_acd.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_3_2_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_1) > 0"
#         label queue_4_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_4_busy for ACD: "marking(BS_1) < num_servers"
#         label server_4_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_2) > 0"
#         label queue_5_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_5_busy for ACD: "marking(BS_2) < num_servers"
#         label server_5_busy for DEVS: "Branch_2_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## hybrid (3,3): 3 tandem + 3 branches

# %%
# %%simasm verify
# // MSRE Verification: hybrid_3_3 EG vs ACD
# // Generated by generate_msre_configs.py
#
# verification hybrid_3_3_eg_acd_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_3_3_eg.simasm"
#         import ACD from "../models/acd/hybrid/hybrid_3_3_acd.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "branch_queue_1 > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_1) > 0"
#         label server_4_busy for EG: "branch_server_1 > 0"
#         label server_4_busy for ACD: "marking(BS_1) < num_servers"
#         label queue_5_nonempty for EG: "branch_queue_2 > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_2) > 0"
#         label server_5_busy for EG: "branch_server_2 > 0"
#         label server_5_busy for ACD: "marking(BS_2) < num_servers"
#         label queue_6_nonempty for EG: "branch_queue_3 > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_3) > 0"
#         label server_6_busy for EG: "branch_server_3 > 0"
#         label server_6_busy for ACD: "marking(BS_3) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             ACD -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             ACD -> server_6_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_3_3 EG vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_3_3_eg_devs_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_3_3_eg.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_3_3_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "branch_queue_1 > 0"
#         label queue_4_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_4_busy for EG: "branch_server_1 > 0"
#         label server_4_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_5_nonempty for EG: "branch_queue_2 > 0"
#         label queue_5_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_5_busy for EG: "branch_server_2 > 0"
#         label server_5_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_6_nonempty for EG: "branch_queue_3 > 0"
#         label queue_6_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_6_busy for EG: "branch_server_3 > 0"
#         label server_6_busy for DEVS: "Branch_3_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_3_3 ACD vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_3_3_acd_devs_msre:
#
#     models:
#         import ACD from "../models/acd/hybrid/hybrid_3_3_acd.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_3_3_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_1) > 0"
#         label queue_4_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_4_busy for ACD: "marking(BS_1) < num_servers"
#         label server_4_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_2) > 0"
#         label queue_5_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_5_busy for ACD: "marking(BS_2) < num_servers"
#         label server_5_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_3) > 0"
#         label queue_6_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_6_busy for ACD: "marking(BS_3) < num_servers"
#         label server_6_busy for DEVS: "Branch_3_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             ACD -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             ACD -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## hybrid (3,4): 3 tandem + 4 branches

# %%
# %%simasm verify
# // MSRE Verification: hybrid_3_4 EG vs ACD
# // Generated by generate_msre_configs.py
#
# verification hybrid_3_4_eg_acd_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_3_4_eg.simasm"
#         import ACD from "../models/acd/hybrid/hybrid_3_4_acd.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "branch_queue_1 > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_1) > 0"
#         label server_4_busy for EG: "branch_server_1 > 0"
#         label server_4_busy for ACD: "marking(BS_1) < num_servers"
#         label queue_5_nonempty for EG: "branch_queue_2 > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_2) > 0"
#         label server_5_busy for EG: "branch_server_2 > 0"
#         label server_5_busy for ACD: "marking(BS_2) < num_servers"
#         label queue_6_nonempty for EG: "branch_queue_3 > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_3) > 0"
#         label server_6_busy for EG: "branch_server_3 > 0"
#         label server_6_busy for ACD: "marking(BS_3) < num_servers"
#         label queue_7_nonempty for EG: "branch_queue_4 > 0"
#         label queue_7_nonempty for ACD: "marking(BQ_4) > 0"
#         label server_7_busy for EG: "branch_server_4 > 0"
#         label server_7_busy for ACD: "marking(BS_4) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             ACD -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             ACD -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             ACD -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             ACD -> server_7_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_3_4 EG vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_3_4_eg_devs_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_3_4_eg.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_3_4_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "branch_queue_1 > 0"
#         label queue_4_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_4_busy for EG: "branch_server_1 > 0"
#         label server_4_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_5_nonempty for EG: "branch_queue_2 > 0"
#         label queue_5_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_5_busy for EG: "branch_server_2 > 0"
#         label server_5_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_6_nonempty for EG: "branch_queue_3 > 0"
#         label queue_6_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_6_busy for EG: "branch_server_3 > 0"
#         label server_6_busy for DEVS: "Branch_3_server_count > 0"
#         label queue_7_nonempty for EG: "branch_queue_4 > 0"
#         label queue_7_nonempty for DEVS: "Branch_4_queue_count > 0"
#         label server_7_busy for EG: "branch_server_4 > 0"
#         label server_7_busy for DEVS: "Branch_4_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_3_4 ACD vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_3_4_acd_devs_msre:
#
#     models:
#         import ACD from "../models/acd/hybrid/hybrid_3_4_acd.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_3_4_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(BQ_1) > 0"
#         label queue_4_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_4_busy for ACD: "marking(BS_1) < num_servers"
#         label server_4_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_2) > 0"
#         label queue_5_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_5_busy for ACD: "marking(BS_2) < num_servers"
#         label server_5_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_3) > 0"
#         label queue_6_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_6_busy for ACD: "marking(BS_3) < num_servers"
#         label server_6_busy for DEVS: "Branch_3_server_count > 0"
#         label queue_7_nonempty for ACD: "marking(BQ_4) > 0"
#         label queue_7_nonempty for DEVS: "Branch_4_queue_count > 0"
#         label server_7_busy for ACD: "marking(BS_4) < num_servers"
#         label server_7_busy for DEVS: "Branch_4_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             ACD -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             ACD -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             ACD -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             ACD -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## hybrid (4,2): 4 tandem + 2 branches

# %%
# %%simasm verify
# // MSRE Verification: hybrid_4_2 EG vs ACD
# // Generated by generate_msre_configs.py
#
# verification hybrid_4_2_eg_acd_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_4_2_eg.simasm"
#         import ACD from "../models/acd/hybrid/hybrid_4_2_acd.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label queue_5_nonempty for EG: "branch_queue_1 > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_1) > 0"
#         label server_5_busy for EG: "branch_server_1 > 0"
#         label server_5_busy for ACD: "marking(BS_1) < num_servers"
#         label queue_6_nonempty for EG: "branch_queue_2 > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_2) > 0"
#         label server_6_busy for EG: "branch_server_2 > 0"
#         label server_6_busy for ACD: "marking(BS_2) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             ACD -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             ACD -> server_6_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_4_2 EG vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_4_2_eg_devs_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_4_2_eg.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_4_2_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for EG: "branch_queue_1 > 0"
#         label queue_5_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_5_busy for EG: "branch_server_1 > 0"
#         label server_5_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_6_nonempty for EG: "branch_queue_2 > 0"
#         label queue_6_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_6_busy for EG: "branch_server_2 > 0"
#         label server_6_busy for DEVS: "Branch_2_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_4_2 ACD vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_4_2_acd_devs_msre:
#
#     models:
#         import ACD from "../models/acd/hybrid/hybrid_4_2_acd.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_4_2_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_1) > 0"
#         label queue_5_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_5_busy for ACD: "marking(BS_1) < num_servers"
#         label server_5_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_2) > 0"
#         label queue_6_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_6_busy for ACD: "marking(BS_2) < num_servers"
#         label server_6_busy for DEVS: "Branch_2_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             ACD -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             ACD -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## hybrid (4,3): 4 tandem + 3 branches

# %%
# %%simasm verify
# // MSRE Verification: hybrid_4_3 EG vs ACD
# // Generated by generate_msre_configs.py
#
# verification hybrid_4_3_eg_acd_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_4_3_eg.simasm"
#         import ACD from "../models/acd/hybrid/hybrid_4_3_acd.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label queue_5_nonempty for EG: "branch_queue_1 > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_1) > 0"
#         label server_5_busy for EG: "branch_server_1 > 0"
#         label server_5_busy for ACD: "marking(BS_1) < num_servers"
#         label queue_6_nonempty for EG: "branch_queue_2 > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_2) > 0"
#         label server_6_busy for EG: "branch_server_2 > 0"
#         label server_6_busy for ACD: "marking(BS_2) < num_servers"
#         label queue_7_nonempty for EG: "branch_queue_3 > 0"
#         label queue_7_nonempty for ACD: "marking(BQ_3) > 0"
#         label server_7_busy for EG: "branch_server_3 > 0"
#         label server_7_busy for ACD: "marking(BS_3) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             ACD -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             ACD -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             ACD -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             ACD -> server_7_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_4_3 EG vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_4_3_eg_devs_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_4_3_eg.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_4_3_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for EG: "branch_queue_1 > 0"
#         label queue_5_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_5_busy for EG: "branch_server_1 > 0"
#         label server_5_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_6_nonempty for EG: "branch_queue_2 > 0"
#         label queue_6_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_6_busy for EG: "branch_server_2 > 0"
#         label server_6_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_7_nonempty for EG: "branch_queue_3 > 0"
#         label queue_7_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_7_busy for EG: "branch_server_3 > 0"
#         label server_7_busy for DEVS: "Branch_3_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_4_3 ACD vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_4_3_acd_devs_msre:
#
#     models:
#         import ACD from "../models/acd/hybrid/hybrid_4_3_acd.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_4_3_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_1) > 0"
#         label queue_5_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_5_busy for ACD: "marking(BS_1) < num_servers"
#         label server_5_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_2) > 0"
#         label queue_6_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_6_busy for ACD: "marking(BS_2) < num_servers"
#         label server_6_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_7_nonempty for ACD: "marking(BQ_3) > 0"
#         label queue_7_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_7_busy for ACD: "marking(BS_3) < num_servers"
#         label server_7_busy for DEVS: "Branch_3_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             ACD -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             ACD -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             ACD -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             ACD -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## hybrid (4,4): 4 tandem + 4 branches

# %%
# %%simasm verify
# // MSRE Verification: hybrid_4_4 EG vs ACD
# // Generated by generate_msre_configs.py
#
# verification hybrid_4_4_eg_acd_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_4_4_eg.simasm"
#         import ACD from "../models/acd/hybrid/hybrid_4_4_acd.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label queue_5_nonempty for EG: "branch_queue_1 > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_1) > 0"
#         label server_5_busy for EG: "branch_server_1 > 0"
#         label server_5_busy for ACD: "marking(BS_1) < num_servers"
#         label queue_6_nonempty for EG: "branch_queue_2 > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_2) > 0"
#         label server_6_busy for EG: "branch_server_2 > 0"
#         label server_6_busy for ACD: "marking(BS_2) < num_servers"
#         label queue_7_nonempty for EG: "branch_queue_3 > 0"
#         label queue_7_nonempty for ACD: "marking(BQ_3) > 0"
#         label server_7_busy for EG: "branch_server_3 > 0"
#         label server_7_busy for ACD: "marking(BS_3) < num_servers"
#         label queue_8_nonempty for EG: "branch_queue_4 > 0"
#         label queue_8_nonempty for ACD: "marking(BQ_4) > 0"
#         label server_8_busy for EG: "branch_server_4 > 0"
#         label server_8_busy for ACD: "marking(BS_4) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             ACD -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             ACD -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             ACD -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             ACD -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             EG -> queue_8_nonempty
#             ACD -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             EG -> server_8_busy
#             ACD -> server_8_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_4_4 EG vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_4_4_eg_devs_msre:
#
#     models:
#         import EG from "../models/eg/hybrid/hybrid_4_4_eg.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_4_4_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for EG: "branch_queue_1 > 0"
#         label queue_5_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_5_busy for EG: "branch_server_1 > 0"
#         label server_5_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_6_nonempty for EG: "branch_queue_2 > 0"
#         label queue_6_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_6_busy for EG: "branch_server_2 > 0"
#         label server_6_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_7_nonempty for EG: "branch_queue_3 > 0"
#         label queue_7_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_7_busy for EG: "branch_server_3 > 0"
#         label server_7_busy for DEVS: "Branch_3_server_count > 0"
#         label queue_8_nonempty for EG: "branch_queue_4 > 0"
#         label queue_8_nonempty for DEVS: "Branch_4_queue_count > 0"
#         label server_8_busy for EG: "branch_server_4 > 0"
#         label server_8_busy for DEVS: "Branch_4_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             EG -> queue_8_nonempty
#             DEVS -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             EG -> server_8_busy
#             DEVS -> server_8_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: hybrid_4_4 ACD vs DEVS
# // Generated by generate_msre_configs.py
#
# verification hybrid_4_4_acd_devs_msre:
#
#     models:
#         import ACD from "../models/acd/hybrid/hybrid_4_4_acd.simasm"
#         import DEVS from "../models/devs/hybrid/hybrid_4_4_devs.simasm"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(BQ_1) > 0"
#         label queue_5_nonempty for DEVS: "Branch_1_queue_count > 0"
#         label server_5_busy for ACD: "marking(BS_1) < num_servers"
#         label server_5_busy for DEVS: "Branch_1_server_count > 0"
#         label queue_6_nonempty for ACD: "marking(BQ_2) > 0"
#         label queue_6_nonempty for DEVS: "Branch_2_queue_count > 0"
#         label server_6_busy for ACD: "marking(BS_2) < num_servers"
#         label server_6_busy for DEVS: "Branch_2_server_count > 0"
#         label queue_7_nonempty for ACD: "marking(BQ_3) > 0"
#         label queue_7_nonempty for DEVS: "Branch_3_queue_count > 0"
#         label server_7_busy for ACD: "marking(BS_3) < num_servers"
#         label server_7_busy for DEVS: "Branch_3_server_count > 0"
#         label queue_8_nonempty for ACD: "marking(BQ_4) > 0"
#         label queue_8_nonempty for DEVS: "Branch_4_queue_count > 0"
#         label server_8_busy for ACD: "marking(BS_4) < num_servers"
#         label server_8_busy for DEVS: "Branch_4_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             ACD -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             ACD -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             ACD -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             ACD -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             ACD -> queue_8_nonempty
#             DEVS -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             ACD -> server_8_busy
#             DEVS -> server_8_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## Summary
#
# All verification cells above should return **EQUIVALENT**. This confirms macro-step refinement equivalence across all three formalism pairs for this topology.
