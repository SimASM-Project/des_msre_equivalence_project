# %% [markdown]
# # MSRE Verification: Tandem Topology
#
# A **tandem queueing network** with $n$ stations in series. Entities arrive at station 1, are served, and proceed sequentially to station $n$. Each station has 5 servers (`service_capacity=5`), exponential inter-arrival times (`iat_mean=1.25`), and exponential service times (`ist_mean=1.0`).
#
# ## Macro-Step Refinement Equivalence (MSRE)
#
# Each section below converts the JSON specification into SimASM via `%%simasm convert`, then verifies that all three formalism translations produce **identical observable labels at every tick boundary** (simulation time advance). The observation level is boolean: `QueueNonEmpty` and `ServerBusy` per station.
#
# **Notebook parameters**: `seed=42`, `run_length=100.0` (fast interactive execution).

# %%
import simasm
assert simasm.__version__ >= "0.8.1", f"Requires simasm >= 0.8.1, got {simasm.__version__}"

# %% [markdown]
# ## $n = 1$

# %%
# %%simasm convert
# convert tandem_1_eg:
#     source: "../input/tandem/tandem_1_eg.json"
#     formalism: event_graph
#     register: "tandem_1_eg"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_1_acd:
#     source: "../input/tandem/tandem_1_acd.json"
#     formalism: acd
#     register: "tandem_1_acd"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_1_devs:
#     source: "../input/tandem/tandem_1_devs.json"
#     formalism: devs
#     register: "tandem_1_devs"
#     print: 30
# endconvert

# %%
# %%simasm verify
# // MSRE Verification: tandem_1 EG vs ACD
#
# verification tandem_1_eg_acd_msre:
#
#     models:
#         import EG from "tandem_1_eg"
#         import ACD from "tandem_1_acd"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_1 EG vs DEVS
#
# verification tandem_1_eg_devs_msre:
#
#     models:
#         import EG from "tandem_1_eg"
#         import DEVS from "tandem_1_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_1 ACD vs DEVS
#
# verification tandem_1_acd_devs_msre:
#
#     models:
#         import ACD from "tandem_1_acd"
#         import DEVS from "tandem_1_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## $n = 2$

# %%
# %%simasm convert
# convert tandem_2_eg:
#     source: "../input/tandem/tandem_2_eg.json"
#     formalism: event_graph
#     register: "tandem_2_eg"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_2_acd:
#     source: "../input/tandem/tandem_2_acd.json"
#     formalism: acd
#     register: "tandem_2_acd"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_2_devs:
#     source: "../input/tandem/tandem_2_devs.json"
#     formalism: devs
#     register: "tandem_2_devs"
#     print: 30
# endconvert

# %%
# %%simasm verify
# // MSRE Verification: tandem_2 EG vs ACD
#
# verification tandem_2_eg_acd_msre:
#
#     models:
#         import EG from "tandem_2_eg"
#         import ACD from "tandem_2_acd"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_2 EG vs DEVS
#
# verification tandem_2_eg_devs_msre:
#
#     models:
#         import EG from "tandem_2_eg"
#         import DEVS from "tandem_2_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_2 ACD vs DEVS
#
# verification tandem_2_acd_devs_msre:
#
#     models:
#         import ACD from "tandem_2_acd"
#         import DEVS from "tandem_2_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## $n = 3$

# %%
# %%simasm convert
# convert tandem_3_eg:
#     source: "../input/tandem/tandem_3_eg.json"
#     formalism: event_graph
#     register: "tandem_3_eg"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_3_acd:
#     source: "../input/tandem/tandem_3_acd.json"
#     formalism: acd
#     register: "tandem_3_acd"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_3_devs:
#     source: "../input/tandem/tandem_3_devs.json"
#     formalism: devs
#     register: "tandem_3_devs"
#     print: 30
# endconvert

# %%
# %%simasm verify
# // MSRE Verification: tandem_3 EG vs ACD
#
# verification tandem_3_eg_acd_msre:
#
#     models:
#         import EG from "tandem_3_eg"
#         import ACD from "tandem_3_acd"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_3 EG vs DEVS
#
# verification tandem_3_eg_devs_msre:
#
#     models:
#         import EG from "tandem_3_eg"
#         import DEVS from "tandem_3_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_3 ACD vs DEVS
#
# verification tandem_3_acd_devs_msre:
#
#     models:
#         import ACD from "tandem_3_acd"
#         import DEVS from "tandem_3_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## $n = 4$

# %%
# %%simasm convert
# convert tandem_4_eg:
#     source: "../input/tandem/tandem_4_eg.json"
#     formalism: event_graph
#     register: "tandem_4_eg"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_4_acd:
#     source: "../input/tandem/tandem_4_acd.json"
#     formalism: acd
#     register: "tandem_4_acd"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_4_devs:
#     source: "../input/tandem/tandem_4_devs.json"
#     formalism: devs
#     register: "tandem_4_devs"
#     print: 30
# endconvert

# %%
# %%simasm verify
# // MSRE Verification: tandem_4 EG vs ACD
#
# verification tandem_4_eg_acd_msre:
#
#     models:
#         import EG from "tandem_4_eg"
#         import ACD from "tandem_4_acd"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_4 EG vs DEVS
#
# verification tandem_4_eg_devs_msre:
#
#     models:
#         import EG from "tandem_4_eg"
#         import DEVS from "tandem_4_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_4 ACD vs DEVS
#
# verification tandem_4_acd_devs_msre:
#
#     models:
#         import ACD from "tandem_4_acd"
#         import DEVS from "tandem_4_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## $n = 5$

# %%
# %%simasm convert
# convert tandem_5_eg:
#     source: "../input/tandem/tandem_5_eg.json"
#     formalism: event_graph
#     register: "tandem_5_eg"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_5_acd:
#     source: "../input/tandem/tandem_5_acd.json"
#     formalism: acd
#     register: "tandem_5_acd"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_5_devs:
#     source: "../input/tandem/tandem_5_devs.json"
#     formalism: devs
#     register: "tandem_5_devs"
#     print: 30
# endconvert

# %%
# %%simasm verify
# // MSRE Verification: tandem_5 EG vs ACD
#
# verification tandem_5_eg_acd_msre:
#
#     models:
#         import EG from "tandem_5_eg"
#         import ACD from "tandem_5_acd"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label queue_5_nonempty for EG: "queue_count_5 > 0"
#         label queue_5_nonempty for ACD: "marking(Q_5) > 0"
#         label server_5_busy for EG: "server_count_5 > 0"
#         label server_5_busy for ACD: "marking(S_5) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_5 EG vs DEVS
#
# verification tandem_5_eg_devs_msre:
#
#     models:
#         import EG from "tandem_5_eg"
#         import DEVS from "tandem_5_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for EG: "queue_count_5 > 0"
#         label queue_5_nonempty for DEVS: "Server_5_queue_count > 0"
#         label server_5_busy for EG: "server_count_5 > 0"
#         label server_5_busy for DEVS: "Server_5_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_5 ACD vs DEVS
#
# verification tandem_5_acd_devs_msre:
#
#     models:
#         import ACD from "tandem_5_acd"
#         import DEVS from "tandem_5_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(Q_5) > 0"
#         label queue_5_nonempty for DEVS: "Server_5_queue_count > 0"
#         label server_5_busy for ACD: "marking(S_5) < num_servers"
#         label server_5_busy for DEVS: "Server_5_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## $n = 7$

# %%
# %%simasm convert
# convert tandem_7_eg:
#     source: "../input/tandem/tandem_7_eg.json"
#     formalism: event_graph
#     register: "tandem_7_eg"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_7_acd:
#     source: "../input/tandem/tandem_7_acd.json"
#     formalism: acd
#     register: "tandem_7_acd"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_7_devs:
#     source: "../input/tandem/tandem_7_devs.json"
#     formalism: devs
#     register: "tandem_7_devs"
#     print: 30
# endconvert

# %%
# %%simasm verify
# // MSRE Verification: tandem_7 EG vs ACD
#
# verification tandem_7_eg_acd_msre:
#
#     models:
#         import EG from "tandem_7_eg"
#         import ACD from "tandem_7_acd"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label queue_5_nonempty for EG: "queue_count_5 > 0"
#         label queue_5_nonempty for ACD: "marking(Q_5) > 0"
#         label server_5_busy for EG: "server_count_5 > 0"
#         label server_5_busy for ACD: "marking(S_5) < num_servers"
#         label queue_6_nonempty for EG: "queue_count_6 > 0"
#         label queue_6_nonempty for ACD: "marking(Q_6) > 0"
#         label server_6_busy for EG: "server_count_6 > 0"
#         label server_6_busy for ACD: "marking(S_6) < num_servers"
#         label queue_7_nonempty for EG: "queue_count_7 > 0"
#         label queue_7_nonempty for ACD: "marking(Q_7) > 0"
#         label server_7_busy for EG: "server_count_7 > 0"
#         label server_7_busy for ACD: "marking(S_7) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             ACD -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             ACD -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             ACD -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             ACD -> server_7_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_7 EG vs DEVS
#
# verification tandem_7_eg_devs_msre:
#
#     models:
#         import EG from "tandem_7_eg"
#         import DEVS from "tandem_7_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for EG: "queue_count_5 > 0"
#         label queue_5_nonempty for DEVS: "Server_5_queue_count > 0"
#         label server_5_busy for EG: "server_count_5 > 0"
#         label server_5_busy for DEVS: "Server_5_server_count > 0"
#         label queue_6_nonempty for EG: "queue_count_6 > 0"
#         label queue_6_nonempty for DEVS: "Server_6_queue_count > 0"
#         label server_6_busy for EG: "server_count_6 > 0"
#         label server_6_busy for DEVS: "Server_6_server_count > 0"
#         label queue_7_nonempty for EG: "queue_count_7 > 0"
#         label queue_7_nonempty for DEVS: "Server_7_queue_count > 0"
#         label server_7_busy for EG: "server_count_7 > 0"
#         label server_7_busy for DEVS: "Server_7_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_7 ACD vs DEVS
#
# verification tandem_7_acd_devs_msre:
#
#     models:
#         import ACD from "tandem_7_acd"
#         import DEVS from "tandem_7_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(Q_5) > 0"
#         label queue_5_nonempty for DEVS: "Server_5_queue_count > 0"
#         label server_5_busy for ACD: "marking(S_5) < num_servers"
#         label server_5_busy for DEVS: "Server_5_server_count > 0"
#         label queue_6_nonempty for ACD: "marking(Q_6) > 0"
#         label queue_6_nonempty for DEVS: "Server_6_queue_count > 0"
#         label server_6_busy for ACD: "marking(S_6) < num_servers"
#         label server_6_busy for DEVS: "Server_6_server_count > 0"
#         label queue_7_nonempty for ACD: "marking(Q_7) > 0"
#         label queue_7_nonempty for DEVS: "Server_7_queue_count > 0"
#         label server_7_busy for ACD: "marking(S_7) < num_servers"
#         label server_7_busy for DEVS: "Server_7_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             ACD -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             ACD -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             ACD -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             ACD -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## $n = 10$

# %%
# %%simasm convert
# convert tandem_10_eg:
#     source: "../input/tandem/tandem_10_eg.json"
#     formalism: event_graph
#     register: "tandem_10_eg"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_10_acd:
#     source: "../input/tandem/tandem_10_acd.json"
#     formalism: acd
#     register: "tandem_10_acd"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_10_devs:
#     source: "../input/tandem/tandem_10_devs.json"
#     formalism: devs
#     register: "tandem_10_devs"
#     print: 30
# endconvert

# %%
# %%simasm verify
# // MSRE Verification: tandem_10 EG vs ACD
#
# verification tandem_10_eg_acd_msre:
#
#     models:
#         import EG from "tandem_10_eg"
#         import ACD from "tandem_10_acd"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label queue_5_nonempty for EG: "queue_count_5 > 0"
#         label queue_5_nonempty for ACD: "marking(Q_5) > 0"
#         label server_5_busy for EG: "server_count_5 > 0"
#         label server_5_busy for ACD: "marking(S_5) < num_servers"
#         label queue_6_nonempty for EG: "queue_count_6 > 0"
#         label queue_6_nonempty for ACD: "marking(Q_6) > 0"
#         label server_6_busy for EG: "server_count_6 > 0"
#         label server_6_busy for ACD: "marking(S_6) < num_servers"
#         label queue_7_nonempty for EG: "queue_count_7 > 0"
#         label queue_7_nonempty for ACD: "marking(Q_7) > 0"
#         label server_7_busy for EG: "server_count_7 > 0"
#         label server_7_busy for ACD: "marking(S_7) < num_servers"
#         label queue_8_nonempty for EG: "queue_count_8 > 0"
#         label queue_8_nonempty for ACD: "marking(Q_8) > 0"
#         label server_8_busy for EG: "server_count_8 > 0"
#         label server_8_busy for ACD: "marking(S_8) < num_servers"
#         label queue_9_nonempty for EG: "queue_count_9 > 0"
#         label queue_9_nonempty for ACD: "marking(Q_9) > 0"
#         label server_9_busy for EG: "server_count_9 > 0"
#         label server_9_busy for ACD: "marking(S_9) < num_servers"
#         label queue_10_nonempty for EG: "queue_count_10 > 0"
#         label queue_10_nonempty for ACD: "marking(Q_10) > 0"
#         label server_10_busy for EG: "server_count_10 > 0"
#         label server_10_busy for ACD: "marking(S_10) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             ACD -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             ACD -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             ACD -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             ACD -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             EG -> queue_8_nonempty
#             ACD -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             EG -> server_8_busy
#             ACD -> server_8_busy
#         endobservable
#         observable queue_9_nonempty:
#             EG -> queue_9_nonempty
#             ACD -> queue_9_nonempty
#         endobservable
#         observable server_9_busy:
#             EG -> server_9_busy
#             ACD -> server_9_busy
#         endobservable
#         observable queue_10_nonempty:
#             EG -> queue_10_nonempty
#             ACD -> queue_10_nonempty
#         endobservable
#         observable server_10_busy:
#             EG -> server_10_busy
#             ACD -> server_10_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_10 EG vs DEVS
#
# verification tandem_10_eg_devs_msre:
#
#     models:
#         import EG from "tandem_10_eg"
#         import DEVS from "tandem_10_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for EG: "queue_count_5 > 0"
#         label queue_5_nonempty for DEVS: "Server_5_queue_count > 0"
#         label server_5_busy for EG: "server_count_5 > 0"
#         label server_5_busy for DEVS: "Server_5_server_count > 0"
#         label queue_6_nonempty for EG: "queue_count_6 > 0"
#         label queue_6_nonempty for DEVS: "Server_6_queue_count > 0"
#         label server_6_busy for EG: "server_count_6 > 0"
#         label server_6_busy for DEVS: "Server_6_server_count > 0"
#         label queue_7_nonempty for EG: "queue_count_7 > 0"
#         label queue_7_nonempty for DEVS: "Server_7_queue_count > 0"
#         label server_7_busy for EG: "server_count_7 > 0"
#         label server_7_busy for DEVS: "Server_7_server_count > 0"
#         label queue_8_nonempty for EG: "queue_count_8 > 0"
#         label queue_8_nonempty for DEVS: "Server_8_queue_count > 0"
#         label server_8_busy for EG: "server_count_8 > 0"
#         label server_8_busy for DEVS: "Server_8_server_count > 0"
#         label queue_9_nonempty for EG: "queue_count_9 > 0"
#         label queue_9_nonempty for DEVS: "Server_9_queue_count > 0"
#         label server_9_busy for EG: "server_count_9 > 0"
#         label server_9_busy for DEVS: "Server_9_server_count > 0"
#         label queue_10_nonempty for EG: "queue_count_10 > 0"
#         label queue_10_nonempty for DEVS: "Server_10_queue_count > 0"
#         label server_10_busy for EG: "server_count_10 > 0"
#         label server_10_busy for DEVS: "Server_10_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             EG -> queue_8_nonempty
#             DEVS -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             EG -> server_8_busy
#             DEVS -> server_8_busy
#         endobservable
#         observable queue_9_nonempty:
#             EG -> queue_9_nonempty
#             DEVS -> queue_9_nonempty
#         endobservable
#         observable server_9_busy:
#             EG -> server_9_busy
#             DEVS -> server_9_busy
#         endobservable
#         observable queue_10_nonempty:
#             EG -> queue_10_nonempty
#             DEVS -> queue_10_nonempty
#         endobservable
#         observable server_10_busy:
#             EG -> server_10_busy
#             DEVS -> server_10_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_10 ACD vs DEVS
#
# verification tandem_10_acd_devs_msre:
#
#     models:
#         import ACD from "tandem_10_acd"
#         import DEVS from "tandem_10_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(Q_5) > 0"
#         label queue_5_nonempty for DEVS: "Server_5_queue_count > 0"
#         label server_5_busy for ACD: "marking(S_5) < num_servers"
#         label server_5_busy for DEVS: "Server_5_server_count > 0"
#         label queue_6_nonempty for ACD: "marking(Q_6) > 0"
#         label queue_6_nonempty for DEVS: "Server_6_queue_count > 0"
#         label server_6_busy for ACD: "marking(S_6) < num_servers"
#         label server_6_busy for DEVS: "Server_6_server_count > 0"
#         label queue_7_nonempty for ACD: "marking(Q_7) > 0"
#         label queue_7_nonempty for DEVS: "Server_7_queue_count > 0"
#         label server_7_busy for ACD: "marking(S_7) < num_servers"
#         label server_7_busy for DEVS: "Server_7_server_count > 0"
#         label queue_8_nonempty for ACD: "marking(Q_8) > 0"
#         label queue_8_nonempty for DEVS: "Server_8_queue_count > 0"
#         label server_8_busy for ACD: "marking(S_8) < num_servers"
#         label server_8_busy for DEVS: "Server_8_server_count > 0"
#         label queue_9_nonempty for ACD: "marking(Q_9) > 0"
#         label queue_9_nonempty for DEVS: "Server_9_queue_count > 0"
#         label server_9_busy for ACD: "marking(S_9) < num_servers"
#         label server_9_busy for DEVS: "Server_9_server_count > 0"
#         label queue_10_nonempty for ACD: "marking(Q_10) > 0"
#         label queue_10_nonempty for DEVS: "Server_10_queue_count > 0"
#         label server_10_busy for ACD: "marking(S_10) < num_servers"
#         label server_10_busy for DEVS: "Server_10_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             ACD -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             ACD -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             ACD -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             ACD -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             ACD -> queue_8_nonempty
#             DEVS -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             ACD -> server_8_busy
#             DEVS -> server_8_busy
#         endobservable
#         observable queue_9_nonempty:
#             ACD -> queue_9_nonempty
#             DEVS -> queue_9_nonempty
#         endobservable
#         observable server_9_busy:
#             ACD -> server_9_busy
#             DEVS -> server_9_busy
#         endobservable
#         observable queue_10_nonempty:
#             ACD -> queue_10_nonempty
#             DEVS -> queue_10_nonempty
#         endobservable
#         observable server_10_busy:
#             ACD -> server_10_busy
#             DEVS -> server_10_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## $n = 15$

# %%
# %%simasm convert
# convert tandem_15_eg:
#     source: "../input/tandem/tandem_15_eg.json"
#     formalism: event_graph
#     register: "tandem_15_eg"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_15_acd:
#     source: "../input/tandem/tandem_15_acd.json"
#     formalism: acd
#     register: "tandem_15_acd"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_15_devs:
#     source: "../input/tandem/tandem_15_devs.json"
#     formalism: devs
#     register: "tandem_15_devs"
#     print: 30
# endconvert

# %%
# %%simasm verify
# // MSRE Verification: tandem_15 EG vs ACD
#
# verification tandem_15_eg_acd_msre:
#
#     models:
#         import EG from "tandem_15_eg"
#         import ACD from "tandem_15_acd"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label queue_5_nonempty for EG: "queue_count_5 > 0"
#         label queue_5_nonempty for ACD: "marking(Q_5) > 0"
#         label server_5_busy for EG: "server_count_5 > 0"
#         label server_5_busy for ACD: "marking(S_5) < num_servers"
#         label queue_6_nonempty for EG: "queue_count_6 > 0"
#         label queue_6_nonempty for ACD: "marking(Q_6) > 0"
#         label server_6_busy for EG: "server_count_6 > 0"
#         label server_6_busy for ACD: "marking(S_6) < num_servers"
#         label queue_7_nonempty for EG: "queue_count_7 > 0"
#         label queue_7_nonempty for ACD: "marking(Q_7) > 0"
#         label server_7_busy for EG: "server_count_7 > 0"
#         label server_7_busy for ACD: "marking(S_7) < num_servers"
#         label queue_8_nonempty for EG: "queue_count_8 > 0"
#         label queue_8_nonempty for ACD: "marking(Q_8) > 0"
#         label server_8_busy for EG: "server_count_8 > 0"
#         label server_8_busy for ACD: "marking(S_8) < num_servers"
#         label queue_9_nonempty for EG: "queue_count_9 > 0"
#         label queue_9_nonempty for ACD: "marking(Q_9) > 0"
#         label server_9_busy for EG: "server_count_9 > 0"
#         label server_9_busy for ACD: "marking(S_9) < num_servers"
#         label queue_10_nonempty for EG: "queue_count_10 > 0"
#         label queue_10_nonempty for ACD: "marking(Q_10) > 0"
#         label server_10_busy for EG: "server_count_10 > 0"
#         label server_10_busy for ACD: "marking(S_10) < num_servers"
#         label queue_11_nonempty for EG: "queue_count_11 > 0"
#         label queue_11_nonempty for ACD: "marking(Q_11) > 0"
#         label server_11_busy for EG: "server_count_11 > 0"
#         label server_11_busy for ACD: "marking(S_11) < num_servers"
#         label queue_12_nonempty for EG: "queue_count_12 > 0"
#         label queue_12_nonempty for ACD: "marking(Q_12) > 0"
#         label server_12_busy for EG: "server_count_12 > 0"
#         label server_12_busy for ACD: "marking(S_12) < num_servers"
#         label queue_13_nonempty for EG: "queue_count_13 > 0"
#         label queue_13_nonempty for ACD: "marking(Q_13) > 0"
#         label server_13_busy for EG: "server_count_13 > 0"
#         label server_13_busy for ACD: "marking(S_13) < num_servers"
#         label queue_14_nonempty for EG: "queue_count_14 > 0"
#         label queue_14_nonempty for ACD: "marking(Q_14) > 0"
#         label server_14_busy for EG: "server_count_14 > 0"
#         label server_14_busy for ACD: "marking(S_14) < num_servers"
#         label queue_15_nonempty for EG: "queue_count_15 > 0"
#         label queue_15_nonempty for ACD: "marking(Q_15) > 0"
#         label server_15_busy for EG: "server_count_15 > 0"
#         label server_15_busy for ACD: "marking(S_15) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             ACD -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             ACD -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             ACD -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             ACD -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             EG -> queue_8_nonempty
#             ACD -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             EG -> server_8_busy
#             ACD -> server_8_busy
#         endobservable
#         observable queue_9_nonempty:
#             EG -> queue_9_nonempty
#             ACD -> queue_9_nonempty
#         endobservable
#         observable server_9_busy:
#             EG -> server_9_busy
#             ACD -> server_9_busy
#         endobservable
#         observable queue_10_nonempty:
#             EG -> queue_10_nonempty
#             ACD -> queue_10_nonempty
#         endobservable
#         observable server_10_busy:
#             EG -> server_10_busy
#             ACD -> server_10_busy
#         endobservable
#         observable queue_11_nonempty:
#             EG -> queue_11_nonempty
#             ACD -> queue_11_nonempty
#         endobservable
#         observable server_11_busy:
#             EG -> server_11_busy
#             ACD -> server_11_busy
#         endobservable
#         observable queue_12_nonempty:
#             EG -> queue_12_nonempty
#             ACD -> queue_12_nonempty
#         endobservable
#         observable server_12_busy:
#             EG -> server_12_busy
#             ACD -> server_12_busy
#         endobservable
#         observable queue_13_nonempty:
#             EG -> queue_13_nonempty
#             ACD -> queue_13_nonempty
#         endobservable
#         observable server_13_busy:
#             EG -> server_13_busy
#             ACD -> server_13_busy
#         endobservable
#         observable queue_14_nonempty:
#             EG -> queue_14_nonempty
#             ACD -> queue_14_nonempty
#         endobservable
#         observable server_14_busy:
#             EG -> server_14_busy
#             ACD -> server_14_busy
#         endobservable
#         observable queue_15_nonempty:
#             EG -> queue_15_nonempty
#             ACD -> queue_15_nonempty
#         endobservable
#         observable server_15_busy:
#             EG -> server_15_busy
#             ACD -> server_15_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_15 EG vs DEVS
#
# verification tandem_15_eg_devs_msre:
#
#     models:
#         import EG from "tandem_15_eg"
#         import DEVS from "tandem_15_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for EG: "queue_count_5 > 0"
#         label queue_5_nonempty for DEVS: "Server_5_queue_count > 0"
#         label server_5_busy for EG: "server_count_5 > 0"
#         label server_5_busy for DEVS: "Server_5_server_count > 0"
#         label queue_6_nonempty for EG: "queue_count_6 > 0"
#         label queue_6_nonempty for DEVS: "Server_6_queue_count > 0"
#         label server_6_busy for EG: "server_count_6 > 0"
#         label server_6_busy for DEVS: "Server_6_server_count > 0"
#         label queue_7_nonempty for EG: "queue_count_7 > 0"
#         label queue_7_nonempty for DEVS: "Server_7_queue_count > 0"
#         label server_7_busy for EG: "server_count_7 > 0"
#         label server_7_busy for DEVS: "Server_7_server_count > 0"
#         label queue_8_nonempty for EG: "queue_count_8 > 0"
#         label queue_8_nonempty for DEVS: "Server_8_queue_count > 0"
#         label server_8_busy for EG: "server_count_8 > 0"
#         label server_8_busy for DEVS: "Server_8_server_count > 0"
#         label queue_9_nonempty for EG: "queue_count_9 > 0"
#         label queue_9_nonempty for DEVS: "Server_9_queue_count > 0"
#         label server_9_busy for EG: "server_count_9 > 0"
#         label server_9_busy for DEVS: "Server_9_server_count > 0"
#         label queue_10_nonempty for EG: "queue_count_10 > 0"
#         label queue_10_nonempty for DEVS: "Server_10_queue_count > 0"
#         label server_10_busy for EG: "server_count_10 > 0"
#         label server_10_busy for DEVS: "Server_10_server_count > 0"
#         label queue_11_nonempty for EG: "queue_count_11 > 0"
#         label queue_11_nonempty for DEVS: "Server_11_queue_count > 0"
#         label server_11_busy for EG: "server_count_11 > 0"
#         label server_11_busy for DEVS: "Server_11_server_count > 0"
#         label queue_12_nonempty for EG: "queue_count_12 > 0"
#         label queue_12_nonempty for DEVS: "Server_12_queue_count > 0"
#         label server_12_busy for EG: "server_count_12 > 0"
#         label server_12_busy for DEVS: "Server_12_server_count > 0"
#         label queue_13_nonempty for EG: "queue_count_13 > 0"
#         label queue_13_nonempty for DEVS: "Server_13_queue_count > 0"
#         label server_13_busy for EG: "server_count_13 > 0"
#         label server_13_busy for DEVS: "Server_13_server_count > 0"
#         label queue_14_nonempty for EG: "queue_count_14 > 0"
#         label queue_14_nonempty for DEVS: "Server_14_queue_count > 0"
#         label server_14_busy for EG: "server_count_14 > 0"
#         label server_14_busy for DEVS: "Server_14_server_count > 0"
#         label queue_15_nonempty for EG: "queue_count_15 > 0"
#         label queue_15_nonempty for DEVS: "Server_15_queue_count > 0"
#         label server_15_busy for EG: "server_count_15 > 0"
#         label server_15_busy for DEVS: "Server_15_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             EG -> queue_8_nonempty
#             DEVS -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             EG -> server_8_busy
#             DEVS -> server_8_busy
#         endobservable
#         observable queue_9_nonempty:
#             EG -> queue_9_nonempty
#             DEVS -> queue_9_nonempty
#         endobservable
#         observable server_9_busy:
#             EG -> server_9_busy
#             DEVS -> server_9_busy
#         endobservable
#         observable queue_10_nonempty:
#             EG -> queue_10_nonempty
#             DEVS -> queue_10_nonempty
#         endobservable
#         observable server_10_busy:
#             EG -> server_10_busy
#             DEVS -> server_10_busy
#         endobservable
#         observable queue_11_nonempty:
#             EG -> queue_11_nonempty
#             DEVS -> queue_11_nonempty
#         endobservable
#         observable server_11_busy:
#             EG -> server_11_busy
#             DEVS -> server_11_busy
#         endobservable
#         observable queue_12_nonempty:
#             EG -> queue_12_nonempty
#             DEVS -> queue_12_nonempty
#         endobservable
#         observable server_12_busy:
#             EG -> server_12_busy
#             DEVS -> server_12_busy
#         endobservable
#         observable queue_13_nonempty:
#             EG -> queue_13_nonempty
#             DEVS -> queue_13_nonempty
#         endobservable
#         observable server_13_busy:
#             EG -> server_13_busy
#             DEVS -> server_13_busy
#         endobservable
#         observable queue_14_nonempty:
#             EG -> queue_14_nonempty
#             DEVS -> queue_14_nonempty
#         endobservable
#         observable server_14_busy:
#             EG -> server_14_busy
#             DEVS -> server_14_busy
#         endobservable
#         observable queue_15_nonempty:
#             EG -> queue_15_nonempty
#             DEVS -> queue_15_nonempty
#         endobservable
#         observable server_15_busy:
#             EG -> server_15_busy
#             DEVS -> server_15_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_15 ACD vs DEVS
#
# verification tandem_15_acd_devs_msre:
#
#     models:
#         import ACD from "tandem_15_acd"
#         import DEVS from "tandem_15_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(Q_5) > 0"
#         label queue_5_nonempty for DEVS: "Server_5_queue_count > 0"
#         label server_5_busy for ACD: "marking(S_5) < num_servers"
#         label server_5_busy for DEVS: "Server_5_server_count > 0"
#         label queue_6_nonempty for ACD: "marking(Q_6) > 0"
#         label queue_6_nonempty for DEVS: "Server_6_queue_count > 0"
#         label server_6_busy for ACD: "marking(S_6) < num_servers"
#         label server_6_busy for DEVS: "Server_6_server_count > 0"
#         label queue_7_nonempty for ACD: "marking(Q_7) > 0"
#         label queue_7_nonempty for DEVS: "Server_7_queue_count > 0"
#         label server_7_busy for ACD: "marking(S_7) < num_servers"
#         label server_7_busy for DEVS: "Server_7_server_count > 0"
#         label queue_8_nonempty for ACD: "marking(Q_8) > 0"
#         label queue_8_nonempty for DEVS: "Server_8_queue_count > 0"
#         label server_8_busy for ACD: "marking(S_8) < num_servers"
#         label server_8_busy for DEVS: "Server_8_server_count > 0"
#         label queue_9_nonempty for ACD: "marking(Q_9) > 0"
#         label queue_9_nonempty for DEVS: "Server_9_queue_count > 0"
#         label server_9_busy for ACD: "marking(S_9) < num_servers"
#         label server_9_busy for DEVS: "Server_9_server_count > 0"
#         label queue_10_nonempty for ACD: "marking(Q_10) > 0"
#         label queue_10_nonempty for DEVS: "Server_10_queue_count > 0"
#         label server_10_busy for ACD: "marking(S_10) < num_servers"
#         label server_10_busy for DEVS: "Server_10_server_count > 0"
#         label queue_11_nonempty for ACD: "marking(Q_11) > 0"
#         label queue_11_nonempty for DEVS: "Server_11_queue_count > 0"
#         label server_11_busy for ACD: "marking(S_11) < num_servers"
#         label server_11_busy for DEVS: "Server_11_server_count > 0"
#         label queue_12_nonempty for ACD: "marking(Q_12) > 0"
#         label queue_12_nonempty for DEVS: "Server_12_queue_count > 0"
#         label server_12_busy for ACD: "marking(S_12) < num_servers"
#         label server_12_busy for DEVS: "Server_12_server_count > 0"
#         label queue_13_nonempty for ACD: "marking(Q_13) > 0"
#         label queue_13_nonempty for DEVS: "Server_13_queue_count > 0"
#         label server_13_busy for ACD: "marking(S_13) < num_servers"
#         label server_13_busy for DEVS: "Server_13_server_count > 0"
#         label queue_14_nonempty for ACD: "marking(Q_14) > 0"
#         label queue_14_nonempty for DEVS: "Server_14_queue_count > 0"
#         label server_14_busy for ACD: "marking(S_14) < num_servers"
#         label server_14_busy for DEVS: "Server_14_server_count > 0"
#         label queue_15_nonempty for ACD: "marking(Q_15) > 0"
#         label queue_15_nonempty for DEVS: "Server_15_queue_count > 0"
#         label server_15_busy for ACD: "marking(S_15) < num_servers"
#         label server_15_busy for DEVS: "Server_15_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             ACD -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             ACD -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             ACD -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             ACD -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             ACD -> queue_8_nonempty
#             DEVS -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             ACD -> server_8_busy
#             DEVS -> server_8_busy
#         endobservable
#         observable queue_9_nonempty:
#             ACD -> queue_9_nonempty
#             DEVS -> queue_9_nonempty
#         endobservable
#         observable server_9_busy:
#             ACD -> server_9_busy
#             DEVS -> server_9_busy
#         endobservable
#         observable queue_10_nonempty:
#             ACD -> queue_10_nonempty
#             DEVS -> queue_10_nonempty
#         endobservable
#         observable server_10_busy:
#             ACD -> server_10_busy
#             DEVS -> server_10_busy
#         endobservable
#         observable queue_11_nonempty:
#             ACD -> queue_11_nonempty
#             DEVS -> queue_11_nonempty
#         endobservable
#         observable server_11_busy:
#             ACD -> server_11_busy
#             DEVS -> server_11_busy
#         endobservable
#         observable queue_12_nonempty:
#             ACD -> queue_12_nonempty
#             DEVS -> queue_12_nonempty
#         endobservable
#         observable server_12_busy:
#             ACD -> server_12_busy
#             DEVS -> server_12_busy
#         endobservable
#         observable queue_13_nonempty:
#             ACD -> queue_13_nonempty
#             DEVS -> queue_13_nonempty
#         endobservable
#         observable server_13_busy:
#             ACD -> server_13_busy
#             DEVS -> server_13_busy
#         endobservable
#         observable queue_14_nonempty:
#             ACD -> queue_14_nonempty
#             DEVS -> queue_14_nonempty
#         endobservable
#         observable server_14_busy:
#             ACD -> server_14_busy
#             DEVS -> server_14_busy
#         endobservable
#         observable queue_15_nonempty:
#             ACD -> queue_15_nonempty
#             DEVS -> queue_15_nonempty
#         endobservable
#         observable server_15_busy:
#             ACD -> server_15_busy
#             DEVS -> server_15_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## $n = 20$

# %%
# %%simasm convert
# convert tandem_20_eg:
#     source: "../input/tandem/tandem_20_eg.json"
#     formalism: event_graph
#     register: "tandem_20_eg"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_20_acd:
#     source: "../input/tandem/tandem_20_acd.json"
#     formalism: acd
#     register: "tandem_20_acd"
#     print: 30
# endconvert

# %%
# %%simasm convert
# convert tandem_20_devs:
#     source: "../input/tandem/tandem_20_devs.json"
#     formalism: devs
#     register: "tandem_20_devs"
#     print: 30
# endconvert

# %%
# %%simasm verify
# // MSRE Verification: tandem_20 EG vs ACD
#
# verification tandem_20_eg_acd_msre:
#
#     models:
#         import EG from "tandem_20_eg"
#         import ACD from "tandem_20_acd"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label queue_5_nonempty for EG: "queue_count_5 > 0"
#         label queue_5_nonempty for ACD: "marking(Q_5) > 0"
#         label server_5_busy for EG: "server_count_5 > 0"
#         label server_5_busy for ACD: "marking(S_5) < num_servers"
#         label queue_6_nonempty for EG: "queue_count_6 > 0"
#         label queue_6_nonempty for ACD: "marking(Q_6) > 0"
#         label server_6_busy for EG: "server_count_6 > 0"
#         label server_6_busy for ACD: "marking(S_6) < num_servers"
#         label queue_7_nonempty for EG: "queue_count_7 > 0"
#         label queue_7_nonempty for ACD: "marking(Q_7) > 0"
#         label server_7_busy for EG: "server_count_7 > 0"
#         label server_7_busy for ACD: "marking(S_7) < num_servers"
#         label queue_8_nonempty for EG: "queue_count_8 > 0"
#         label queue_8_nonempty for ACD: "marking(Q_8) > 0"
#         label server_8_busy for EG: "server_count_8 > 0"
#         label server_8_busy for ACD: "marking(S_8) < num_servers"
#         label queue_9_nonempty for EG: "queue_count_9 > 0"
#         label queue_9_nonempty for ACD: "marking(Q_9) > 0"
#         label server_9_busy for EG: "server_count_9 > 0"
#         label server_9_busy for ACD: "marking(S_9) < num_servers"
#         label queue_10_nonempty for EG: "queue_count_10 > 0"
#         label queue_10_nonempty for ACD: "marking(Q_10) > 0"
#         label server_10_busy for EG: "server_count_10 > 0"
#         label server_10_busy for ACD: "marking(S_10) < num_servers"
#         label queue_11_nonempty for EG: "queue_count_11 > 0"
#         label queue_11_nonempty for ACD: "marking(Q_11) > 0"
#         label server_11_busy for EG: "server_count_11 > 0"
#         label server_11_busy for ACD: "marking(S_11) < num_servers"
#         label queue_12_nonempty for EG: "queue_count_12 > 0"
#         label queue_12_nonempty for ACD: "marking(Q_12) > 0"
#         label server_12_busy for EG: "server_count_12 > 0"
#         label server_12_busy for ACD: "marking(S_12) < num_servers"
#         label queue_13_nonempty for EG: "queue_count_13 > 0"
#         label queue_13_nonempty for ACD: "marking(Q_13) > 0"
#         label server_13_busy for EG: "server_count_13 > 0"
#         label server_13_busy for ACD: "marking(S_13) < num_servers"
#         label queue_14_nonempty for EG: "queue_count_14 > 0"
#         label queue_14_nonempty for ACD: "marking(Q_14) > 0"
#         label server_14_busy for EG: "server_count_14 > 0"
#         label server_14_busy for ACD: "marking(S_14) < num_servers"
#         label queue_15_nonempty for EG: "queue_count_15 > 0"
#         label queue_15_nonempty for ACD: "marking(Q_15) > 0"
#         label server_15_busy for EG: "server_count_15 > 0"
#         label server_15_busy for ACD: "marking(S_15) < num_servers"
#         label queue_16_nonempty for EG: "queue_count_16 > 0"
#         label queue_16_nonempty for ACD: "marking(Q_16) > 0"
#         label server_16_busy for EG: "server_count_16 > 0"
#         label server_16_busy for ACD: "marking(S_16) < num_servers"
#         label queue_17_nonempty for EG: "queue_count_17 > 0"
#         label queue_17_nonempty for ACD: "marking(Q_17) > 0"
#         label server_17_busy for EG: "server_count_17 > 0"
#         label server_17_busy for ACD: "marking(S_17) < num_servers"
#         label queue_18_nonempty for EG: "queue_count_18 > 0"
#         label queue_18_nonempty for ACD: "marking(Q_18) > 0"
#         label server_18_busy for EG: "server_count_18 > 0"
#         label server_18_busy for ACD: "marking(S_18) < num_servers"
#         label queue_19_nonempty for EG: "queue_count_19 > 0"
#         label queue_19_nonempty for ACD: "marking(Q_19) > 0"
#         label server_19_busy for EG: "server_count_19 > 0"
#         label server_19_busy for ACD: "marking(S_19) < num_servers"
#         label queue_20_nonempty for EG: "queue_count_20 > 0"
#         label queue_20_nonempty for ACD: "marking(Q_20) > 0"
#         label server_20_busy for EG: "server_count_20 > 0"
#         label server_20_busy for ACD: "marking(S_20) < num_servers"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             ACD -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             ACD -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             ACD -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             ACD -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             ACD -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             ACD -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             ACD -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             ACD -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             ACD -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             ACD -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             ACD -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             ACD -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             ACD -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             ACD -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             EG -> queue_8_nonempty
#             ACD -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             EG -> server_8_busy
#             ACD -> server_8_busy
#         endobservable
#         observable queue_9_nonempty:
#             EG -> queue_9_nonempty
#             ACD -> queue_9_nonempty
#         endobservable
#         observable server_9_busy:
#             EG -> server_9_busy
#             ACD -> server_9_busy
#         endobservable
#         observable queue_10_nonempty:
#             EG -> queue_10_nonempty
#             ACD -> queue_10_nonempty
#         endobservable
#         observable server_10_busy:
#             EG -> server_10_busy
#             ACD -> server_10_busy
#         endobservable
#         observable queue_11_nonempty:
#             EG -> queue_11_nonempty
#             ACD -> queue_11_nonempty
#         endobservable
#         observable server_11_busy:
#             EG -> server_11_busy
#             ACD -> server_11_busy
#         endobservable
#         observable queue_12_nonempty:
#             EG -> queue_12_nonempty
#             ACD -> queue_12_nonempty
#         endobservable
#         observable server_12_busy:
#             EG -> server_12_busy
#             ACD -> server_12_busy
#         endobservable
#         observable queue_13_nonempty:
#             EG -> queue_13_nonempty
#             ACD -> queue_13_nonempty
#         endobservable
#         observable server_13_busy:
#             EG -> server_13_busy
#             ACD -> server_13_busy
#         endobservable
#         observable queue_14_nonempty:
#             EG -> queue_14_nonempty
#             ACD -> queue_14_nonempty
#         endobservable
#         observable server_14_busy:
#             EG -> server_14_busy
#             ACD -> server_14_busy
#         endobservable
#         observable queue_15_nonempty:
#             EG -> queue_15_nonempty
#             ACD -> queue_15_nonempty
#         endobservable
#         observable server_15_busy:
#             EG -> server_15_busy
#             ACD -> server_15_busy
#         endobservable
#         observable queue_16_nonempty:
#             EG -> queue_16_nonempty
#             ACD -> queue_16_nonempty
#         endobservable
#         observable server_16_busy:
#             EG -> server_16_busy
#             ACD -> server_16_busy
#         endobservable
#         observable queue_17_nonempty:
#             EG -> queue_17_nonempty
#             ACD -> queue_17_nonempty
#         endobservable
#         observable server_17_busy:
#             EG -> server_17_busy
#             ACD -> server_17_busy
#         endobservable
#         observable queue_18_nonempty:
#             EG -> queue_18_nonempty
#             ACD -> queue_18_nonempty
#         endobservable
#         observable server_18_busy:
#             EG -> server_18_busy
#             ACD -> server_18_busy
#         endobservable
#         observable queue_19_nonempty:
#             EG -> queue_19_nonempty
#             ACD -> queue_19_nonempty
#         endobservable
#         observable server_19_busy:
#             EG -> server_19_busy
#             ACD -> server_19_busy
#         endobservable
#         observable queue_20_nonempty:
#             EG -> queue_20_nonempty
#             ACD -> queue_20_nonempty
#         endobservable
#         observable server_20_busy:
#             EG -> server_20_busy
#             ACD -> server_20_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_20 EG vs DEVS
#
# verification tandem_20_eg_devs_msre:
#
#     models:
#         import EG from "tandem_20_eg"
#         import DEVS from "tandem_20_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for EG: "queue_count_1 > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for EG: "server_count_1 > 0"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for EG: "queue_count_2 > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for EG: "server_count_2 > 0"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for EG: "queue_count_3 > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for EG: "server_count_3 > 0"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for EG: "queue_count_4 > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for EG: "server_count_4 > 0"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for EG: "queue_count_5 > 0"
#         label queue_5_nonempty for DEVS: "Server_5_queue_count > 0"
#         label server_5_busy for EG: "server_count_5 > 0"
#         label server_5_busy for DEVS: "Server_5_server_count > 0"
#         label queue_6_nonempty for EG: "queue_count_6 > 0"
#         label queue_6_nonempty for DEVS: "Server_6_queue_count > 0"
#         label server_6_busy for EG: "server_count_6 > 0"
#         label server_6_busy for DEVS: "Server_6_server_count > 0"
#         label queue_7_nonempty for EG: "queue_count_7 > 0"
#         label queue_7_nonempty for DEVS: "Server_7_queue_count > 0"
#         label server_7_busy for EG: "server_count_7 > 0"
#         label server_7_busy for DEVS: "Server_7_server_count > 0"
#         label queue_8_nonempty for EG: "queue_count_8 > 0"
#         label queue_8_nonempty for DEVS: "Server_8_queue_count > 0"
#         label server_8_busy for EG: "server_count_8 > 0"
#         label server_8_busy for DEVS: "Server_8_server_count > 0"
#         label queue_9_nonempty for EG: "queue_count_9 > 0"
#         label queue_9_nonempty for DEVS: "Server_9_queue_count > 0"
#         label server_9_busy for EG: "server_count_9 > 0"
#         label server_9_busy for DEVS: "Server_9_server_count > 0"
#         label queue_10_nonempty for EG: "queue_count_10 > 0"
#         label queue_10_nonempty for DEVS: "Server_10_queue_count > 0"
#         label server_10_busy for EG: "server_count_10 > 0"
#         label server_10_busy for DEVS: "Server_10_server_count > 0"
#         label queue_11_nonempty for EG: "queue_count_11 > 0"
#         label queue_11_nonempty for DEVS: "Server_11_queue_count > 0"
#         label server_11_busy for EG: "server_count_11 > 0"
#         label server_11_busy for DEVS: "Server_11_server_count > 0"
#         label queue_12_nonempty for EG: "queue_count_12 > 0"
#         label queue_12_nonempty for DEVS: "Server_12_queue_count > 0"
#         label server_12_busy for EG: "server_count_12 > 0"
#         label server_12_busy for DEVS: "Server_12_server_count > 0"
#         label queue_13_nonempty for EG: "queue_count_13 > 0"
#         label queue_13_nonempty for DEVS: "Server_13_queue_count > 0"
#         label server_13_busy for EG: "server_count_13 > 0"
#         label server_13_busy for DEVS: "Server_13_server_count > 0"
#         label queue_14_nonempty for EG: "queue_count_14 > 0"
#         label queue_14_nonempty for DEVS: "Server_14_queue_count > 0"
#         label server_14_busy for EG: "server_count_14 > 0"
#         label server_14_busy for DEVS: "Server_14_server_count > 0"
#         label queue_15_nonempty for EG: "queue_count_15 > 0"
#         label queue_15_nonempty for DEVS: "Server_15_queue_count > 0"
#         label server_15_busy for EG: "server_count_15 > 0"
#         label server_15_busy for DEVS: "Server_15_server_count > 0"
#         label queue_16_nonempty for EG: "queue_count_16 > 0"
#         label queue_16_nonempty for DEVS: "Server_16_queue_count > 0"
#         label server_16_busy for EG: "server_count_16 > 0"
#         label server_16_busy for DEVS: "Server_16_server_count > 0"
#         label queue_17_nonempty for EG: "queue_count_17 > 0"
#         label queue_17_nonempty for DEVS: "Server_17_queue_count > 0"
#         label server_17_busy for EG: "server_count_17 > 0"
#         label server_17_busy for DEVS: "Server_17_server_count > 0"
#         label queue_18_nonempty for EG: "queue_count_18 > 0"
#         label queue_18_nonempty for DEVS: "Server_18_queue_count > 0"
#         label server_18_busy for EG: "server_count_18 > 0"
#         label server_18_busy for DEVS: "Server_18_server_count > 0"
#         label queue_19_nonempty for EG: "queue_count_19 > 0"
#         label queue_19_nonempty for DEVS: "Server_19_queue_count > 0"
#         label server_19_busy for EG: "server_count_19 > 0"
#         label server_19_busy for DEVS: "Server_19_server_count > 0"
#         label queue_20_nonempty for EG: "queue_count_20 > 0"
#         label queue_20_nonempty for DEVS: "Server_20_queue_count > 0"
#         label server_20_busy for EG: "server_count_20 > 0"
#         label server_20_busy for DEVS: "Server_20_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             EG -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             EG -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             EG -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             EG -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             EG -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             EG -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             EG -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             EG -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             EG -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             EG -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             EG -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             EG -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             EG -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             EG -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             EG -> queue_8_nonempty
#             DEVS -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             EG -> server_8_busy
#             DEVS -> server_8_busy
#         endobservable
#         observable queue_9_nonempty:
#             EG -> queue_9_nonempty
#             DEVS -> queue_9_nonempty
#         endobservable
#         observable server_9_busy:
#             EG -> server_9_busy
#             DEVS -> server_9_busy
#         endobservable
#         observable queue_10_nonempty:
#             EG -> queue_10_nonempty
#             DEVS -> queue_10_nonempty
#         endobservable
#         observable server_10_busy:
#             EG -> server_10_busy
#             DEVS -> server_10_busy
#         endobservable
#         observable queue_11_nonempty:
#             EG -> queue_11_nonempty
#             DEVS -> queue_11_nonempty
#         endobservable
#         observable server_11_busy:
#             EG -> server_11_busy
#             DEVS -> server_11_busy
#         endobservable
#         observable queue_12_nonempty:
#             EG -> queue_12_nonempty
#             DEVS -> queue_12_nonempty
#         endobservable
#         observable server_12_busy:
#             EG -> server_12_busy
#             DEVS -> server_12_busy
#         endobservable
#         observable queue_13_nonempty:
#             EG -> queue_13_nonempty
#             DEVS -> queue_13_nonempty
#         endobservable
#         observable server_13_busy:
#             EG -> server_13_busy
#             DEVS -> server_13_busy
#         endobservable
#         observable queue_14_nonempty:
#             EG -> queue_14_nonempty
#             DEVS -> queue_14_nonempty
#         endobservable
#         observable server_14_busy:
#             EG -> server_14_busy
#             DEVS -> server_14_busy
#         endobservable
#         observable queue_15_nonempty:
#             EG -> queue_15_nonempty
#             DEVS -> queue_15_nonempty
#         endobservable
#         observable server_15_busy:
#             EG -> server_15_busy
#             DEVS -> server_15_busy
#         endobservable
#         observable queue_16_nonempty:
#             EG -> queue_16_nonempty
#             DEVS -> queue_16_nonempty
#         endobservable
#         observable server_16_busy:
#             EG -> server_16_busy
#             DEVS -> server_16_busy
#         endobservable
#         observable queue_17_nonempty:
#             EG -> queue_17_nonempty
#             DEVS -> queue_17_nonempty
#         endobservable
#         observable server_17_busy:
#             EG -> server_17_busy
#             DEVS -> server_17_busy
#         endobservable
#         observable queue_18_nonempty:
#             EG -> queue_18_nonempty
#             DEVS -> queue_18_nonempty
#         endobservable
#         observable server_18_busy:
#             EG -> server_18_busy
#             DEVS -> server_18_busy
#         endobservable
#         observable queue_19_nonempty:
#             EG -> queue_19_nonempty
#             DEVS -> queue_19_nonempty
#         endobservable
#         observable server_19_busy:
#             EG -> server_19_busy
#             DEVS -> server_19_busy
#         endobservable
#         observable queue_20_nonempty:
#             EG -> queue_20_nonempty
#             DEVS -> queue_20_nonempty
#         endobservable
#         observable server_20_busy:
#             EG -> server_20_busy
#             DEVS -> server_20_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %%
# %%simasm verify
# // MSRE Verification: tandem_20 ACD vs DEVS
#
# verification tandem_20_acd_devs_msre:
#
#     models:
#         import ACD from "tandem_20_acd"
#         import DEVS from "tandem_20_devs"
#     endmodels
#
#     seed: 42
#
#     labels:
#         label queue_1_nonempty for ACD: "marking(Q_1) > 0"
#         label queue_1_nonempty for DEVS: "Server_1_queue_count > 0"
#         label server_1_busy for ACD: "marking(S_1) < num_servers"
#         label server_1_busy for DEVS: "Server_1_server_count > 0"
#         label queue_2_nonempty for ACD: "marking(Q_2) > 0"
#         label queue_2_nonempty for DEVS: "Server_2_queue_count > 0"
#         label server_2_busy for ACD: "marking(S_2) < num_servers"
#         label server_2_busy for DEVS: "Server_2_server_count > 0"
#         label queue_3_nonempty for ACD: "marking(Q_3) > 0"
#         label queue_3_nonempty for DEVS: "Server_3_queue_count > 0"
#         label server_3_busy for ACD: "marking(S_3) < num_servers"
#         label server_3_busy for DEVS: "Server_3_server_count > 0"
#         label queue_4_nonempty for ACD: "marking(Q_4) > 0"
#         label queue_4_nonempty for DEVS: "Server_4_queue_count > 0"
#         label server_4_busy for ACD: "marking(S_4) < num_servers"
#         label server_4_busy for DEVS: "Server_4_server_count > 0"
#         label queue_5_nonempty for ACD: "marking(Q_5) > 0"
#         label queue_5_nonempty for DEVS: "Server_5_queue_count > 0"
#         label server_5_busy for ACD: "marking(S_5) < num_servers"
#         label server_5_busy for DEVS: "Server_5_server_count > 0"
#         label queue_6_nonempty for ACD: "marking(Q_6) > 0"
#         label queue_6_nonempty for DEVS: "Server_6_queue_count > 0"
#         label server_6_busy for ACD: "marking(S_6) < num_servers"
#         label server_6_busy for DEVS: "Server_6_server_count > 0"
#         label queue_7_nonempty for ACD: "marking(Q_7) > 0"
#         label queue_7_nonempty for DEVS: "Server_7_queue_count > 0"
#         label server_7_busy for ACD: "marking(S_7) < num_servers"
#         label server_7_busy for DEVS: "Server_7_server_count > 0"
#         label queue_8_nonempty for ACD: "marking(Q_8) > 0"
#         label queue_8_nonempty for DEVS: "Server_8_queue_count > 0"
#         label server_8_busy for ACD: "marking(S_8) < num_servers"
#         label server_8_busy for DEVS: "Server_8_server_count > 0"
#         label queue_9_nonempty for ACD: "marking(Q_9) > 0"
#         label queue_9_nonempty for DEVS: "Server_9_queue_count > 0"
#         label server_9_busy for ACD: "marking(S_9) < num_servers"
#         label server_9_busy for DEVS: "Server_9_server_count > 0"
#         label queue_10_nonempty for ACD: "marking(Q_10) > 0"
#         label queue_10_nonempty for DEVS: "Server_10_queue_count > 0"
#         label server_10_busy for ACD: "marking(S_10) < num_servers"
#         label server_10_busy for DEVS: "Server_10_server_count > 0"
#         label queue_11_nonempty for ACD: "marking(Q_11) > 0"
#         label queue_11_nonempty for DEVS: "Server_11_queue_count > 0"
#         label server_11_busy for ACD: "marking(S_11) < num_servers"
#         label server_11_busy for DEVS: "Server_11_server_count > 0"
#         label queue_12_nonempty for ACD: "marking(Q_12) > 0"
#         label queue_12_nonempty for DEVS: "Server_12_queue_count > 0"
#         label server_12_busy for ACD: "marking(S_12) < num_servers"
#         label server_12_busy for DEVS: "Server_12_server_count > 0"
#         label queue_13_nonempty for ACD: "marking(Q_13) > 0"
#         label queue_13_nonempty for DEVS: "Server_13_queue_count > 0"
#         label server_13_busy for ACD: "marking(S_13) < num_servers"
#         label server_13_busy for DEVS: "Server_13_server_count > 0"
#         label queue_14_nonempty for ACD: "marking(Q_14) > 0"
#         label queue_14_nonempty for DEVS: "Server_14_queue_count > 0"
#         label server_14_busy for ACD: "marking(S_14) < num_servers"
#         label server_14_busy for DEVS: "Server_14_server_count > 0"
#         label queue_15_nonempty for ACD: "marking(Q_15) > 0"
#         label queue_15_nonempty for DEVS: "Server_15_queue_count > 0"
#         label server_15_busy for ACD: "marking(S_15) < num_servers"
#         label server_15_busy for DEVS: "Server_15_server_count > 0"
#         label queue_16_nonempty for ACD: "marking(Q_16) > 0"
#         label queue_16_nonempty for DEVS: "Server_16_queue_count > 0"
#         label server_16_busy for ACD: "marking(S_16) < num_servers"
#         label server_16_busy for DEVS: "Server_16_server_count > 0"
#         label queue_17_nonempty for ACD: "marking(Q_17) > 0"
#         label queue_17_nonempty for DEVS: "Server_17_queue_count > 0"
#         label server_17_busy for ACD: "marking(S_17) < num_servers"
#         label server_17_busy for DEVS: "Server_17_server_count > 0"
#         label queue_18_nonempty for ACD: "marking(Q_18) > 0"
#         label queue_18_nonempty for DEVS: "Server_18_queue_count > 0"
#         label server_18_busy for ACD: "marking(S_18) < num_servers"
#         label server_18_busy for DEVS: "Server_18_server_count > 0"
#         label queue_19_nonempty for ACD: "marking(Q_19) > 0"
#         label queue_19_nonempty for DEVS: "Server_19_queue_count > 0"
#         label server_19_busy for ACD: "marking(S_19) < num_servers"
#         label server_19_busy for DEVS: "Server_19_server_count > 0"
#         label queue_20_nonempty for ACD: "marking(Q_20) > 0"
#         label queue_20_nonempty for DEVS: "Server_20_queue_count > 0"
#         label server_20_busy for ACD: "marking(S_20) < num_servers"
#         label server_20_busy for DEVS: "Server_20_server_count > 0"
#     endlabels
#
#     observables:
#         observable queue_1_nonempty:
#             ACD -> queue_1_nonempty
#             DEVS -> queue_1_nonempty
#         endobservable
#         observable server_1_busy:
#             ACD -> server_1_busy
#             DEVS -> server_1_busy
#         endobservable
#         observable queue_2_nonempty:
#             ACD -> queue_2_nonempty
#             DEVS -> queue_2_nonempty
#         endobservable
#         observable server_2_busy:
#             ACD -> server_2_busy
#             DEVS -> server_2_busy
#         endobservable
#         observable queue_3_nonempty:
#             ACD -> queue_3_nonempty
#             DEVS -> queue_3_nonempty
#         endobservable
#         observable server_3_busy:
#             ACD -> server_3_busy
#             DEVS -> server_3_busy
#         endobservable
#         observable queue_4_nonempty:
#             ACD -> queue_4_nonempty
#             DEVS -> queue_4_nonempty
#         endobservable
#         observable server_4_busy:
#             ACD -> server_4_busy
#             DEVS -> server_4_busy
#         endobservable
#         observable queue_5_nonempty:
#             ACD -> queue_5_nonempty
#             DEVS -> queue_5_nonempty
#         endobservable
#         observable server_5_busy:
#             ACD -> server_5_busy
#             DEVS -> server_5_busy
#         endobservable
#         observable queue_6_nonempty:
#             ACD -> queue_6_nonempty
#             DEVS -> queue_6_nonempty
#         endobservable
#         observable server_6_busy:
#             ACD -> server_6_busy
#             DEVS -> server_6_busy
#         endobservable
#         observable queue_7_nonempty:
#             ACD -> queue_7_nonempty
#             DEVS -> queue_7_nonempty
#         endobservable
#         observable server_7_busy:
#             ACD -> server_7_busy
#             DEVS -> server_7_busy
#         endobservable
#         observable queue_8_nonempty:
#             ACD -> queue_8_nonempty
#             DEVS -> queue_8_nonempty
#         endobservable
#         observable server_8_busy:
#             ACD -> server_8_busy
#             DEVS -> server_8_busy
#         endobservable
#         observable queue_9_nonempty:
#             ACD -> queue_9_nonempty
#             DEVS -> queue_9_nonempty
#         endobservable
#         observable server_9_busy:
#             ACD -> server_9_busy
#             DEVS -> server_9_busy
#         endobservable
#         observable queue_10_nonempty:
#             ACD -> queue_10_nonempty
#             DEVS -> queue_10_nonempty
#         endobservable
#         observable server_10_busy:
#             ACD -> server_10_busy
#             DEVS -> server_10_busy
#         endobservable
#         observable queue_11_nonempty:
#             ACD -> queue_11_nonempty
#             DEVS -> queue_11_nonempty
#         endobservable
#         observable server_11_busy:
#             ACD -> server_11_busy
#             DEVS -> server_11_busy
#         endobservable
#         observable queue_12_nonempty:
#             ACD -> queue_12_nonempty
#             DEVS -> queue_12_nonempty
#         endobservable
#         observable server_12_busy:
#             ACD -> server_12_busy
#             DEVS -> server_12_busy
#         endobservable
#         observable queue_13_nonempty:
#             ACD -> queue_13_nonempty
#             DEVS -> queue_13_nonempty
#         endobservable
#         observable server_13_busy:
#             ACD -> server_13_busy
#             DEVS -> server_13_busy
#         endobservable
#         observable queue_14_nonempty:
#             ACD -> queue_14_nonempty
#             DEVS -> queue_14_nonempty
#         endobservable
#         observable server_14_busy:
#             ACD -> server_14_busy
#             DEVS -> server_14_busy
#         endobservable
#         observable queue_15_nonempty:
#             ACD -> queue_15_nonempty
#             DEVS -> queue_15_nonempty
#         endobservable
#         observable server_15_busy:
#             ACD -> server_15_busy
#             DEVS -> server_15_busy
#         endobservable
#         observable queue_16_nonempty:
#             ACD -> queue_16_nonempty
#             DEVS -> queue_16_nonempty
#         endobservable
#         observable server_16_busy:
#             ACD -> server_16_busy
#             DEVS -> server_16_busy
#         endobservable
#         observable queue_17_nonempty:
#             ACD -> queue_17_nonempty
#             DEVS -> queue_17_nonempty
#         endobservable
#         observable server_17_busy:
#             ACD -> server_17_busy
#             DEVS -> server_17_busy
#         endobservable
#         observable queue_18_nonempty:
#             ACD -> queue_18_nonempty
#             DEVS -> queue_18_nonempty
#         endobservable
#         observable server_18_busy:
#             ACD -> server_18_busy
#             DEVS -> server_18_busy
#         endobservable
#         observable queue_19_nonempty:
#             ACD -> queue_19_nonempty
#             DEVS -> queue_19_nonempty
#         endobservable
#         observable server_19_busy:
#             ACD -> server_19_busy
#             DEVS -> server_19_busy
#         endobservable
#         observable queue_20_nonempty:
#             ACD -> queue_20_nonempty
#             DEVS -> queue_20_nonempty
#         endobservable
#         observable server_20_busy:
#             ACD -> server_20_busy
#             DEVS -> server_20_busy
#         endobservable
#     endobservables
#
#     check:
#         type: macro_step_refinement
#         run_length: 100.0
#         timeout: 60
#     endcheck
#
#     output:
#         format: "json"
#         include_counterexample: true
#     endoutput
#
# endverification

# %% [markdown]
# ## Summary
#
# All verification cells above should return **EQUIVALENT**. This confirms macro-step refinement equivalence across all three formalism pairs for this topology.
